# %% [markdown]
# <a href="https://colab.research.google.com/github/luigiselmi/dl_remote_sensing/blob/main/experiments/epfl_building_footprints_xception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rooftop segmentation (U-Net Xception-style model)
# In this notebook we implement a deep learning model for the semantic segmentation task. We will use images of rooftops extracted from satellite images. The target of the model is to classify all the pixels in an image that belong to a rooftop. The model used for the segmentation task is based on the encoder-decoder architecture.

# %%
import os
from pathlib import Path
from zipfile import ZipFile
import matplotlib.pyplot as plt
from skimage import io
from skimage import exposure
from skimage.io import imsave, imread
import numpy as np
from sklearn.metrics import jaccard_score
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.utils import array_to_img, load_img, img_to_array
import warnings
warnings.filterwarnings('ignore')
print("NumPy version: %s"%np.__version__)
print('Tensorflow version: {:s}'.format(tf.__version__))
print('Keras version. {}'.format(keras.__version__))
# Out:
# NumPy version: 2.0.2
# Tensorflow version: 2.18.0
# Keras version. 3.8.0

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.6 gigabytes of available RAM

# %% [markdown]
# ## The dataset
# We use the data from [Cadei et al - Detecting available rooftop area from satellite images to install photovoltaic panels](https://github.com/riccardocadei/photovoltaic-detection/tree/main) to implement a semantic segmentation model for the extraction of building footprints from satellite images. Train, validation, and test data are provided in separate zip files that contain a total of 305 RGB images and masks in binary digits, 0 and 1, as labels, in the PNG format. The size of the images is 250x250, that will be reduced to 224x224, and the resolution is 0.25x0.25 $m^2$

# %%
# !wget -q --show-progress https://github.com/luigiselmi/dl_tensorflow/raw/refs/heads/main/data/epfl_buildings/epfl_buildings_train.zip
# Out:
# epfl_buildings_trai 100%[===================>]  35.27M  --.-KB/s    in 0.09s

# %%
# !wget -q --show-progress https://github.com/luigiselmi/dl_tensorflow/raw/refs/heads/main/data/epfl_buildings/epfl_buildings_test.zip
# Out:
# epfl_buildings_test 100%[===================>]   4.50M  --.-KB/s    in 0.01s

# %%
# !wget -q --show-progress https://github.com/luigiselmi/dl_tensorflow/raw/refs/heads/main/data/epfl_buildings/epfl_buildings_val.zip
# Out:
# epfl_buildings_val. 100%[===================>]   4.32M  --.-KB/s    in 0.02s

# %%
DATADIR = '.'
with ZipFile(f'{DATADIR}/epfl_buildings_train.zip', 'r') as zipObj:
   zipObj.extractall(path=f'{DATADIR}/')

# %%
with ZipFile(f'{DATADIR}/epfl_buildings_test.zip', 'r') as zipObj:
   zipObj.extractall(path=f'{DATADIR}/')

# %%
with ZipFile(f'{DATADIR}/epfl_buildings_val.zip', 'r') as zipObj:
   zipObj.extractall(path=f'{DATADIR}/')

# %% [markdown]
# The train, validation and test directories contain two subdirectories: images/ and labels/

# %%
p_train = Path('/content/train/')
train_paths = []
[train_paths.append(sub_folder) for sub_folder in p_train.iterdir() if sub_folder.is_dir()]
train_images_path = train_paths[0]
train_labels_path = train_paths[1]

# %%
p_val = Path('/content/val/')
val_paths = []
[val_paths.append(sub_folder) for sub_folder in p_val.iterdir() if sub_folder.is_dir()]
val_images_path = val_paths[0]
val_labels_path = val_paths[1]

# %%
p_test = Path('/content/test/')
test_paths = []
[test_paths.append(sub_folder) for sub_folder in p_test.iterdir() if sub_folder.is_dir()]
test_images_path = test_paths[0]
test_labels_path = test_paths[1]

# %% [markdown]
# We create lists of the images and masks in each train, validation, and test set.

# %%
def create_file_list(raster_path):
    """
    This function extracts the raster file paths (png images or masks) in the
    folder path and puts them in a list. The list is sorted in order to have
    each image and mask with the same index
    """
    file_list = []
    for file in os.listdir(raster_path):
        if file.endswith(".png"):
            file_list.append(os.path.join(raster_path, file))

    return sorted(file_list)

# %%
train_images_list = create_file_list(train_images_path)
print('Number of train images: {:d}'.format(len(train_images_list)))
# Out:
# Number of train images: 244

# %%
val_images_list = create_file_list(val_images_path)
print('Number of validation images: {:d}'.format(len(val_images_list)))
# Out:
# Number of validation images: 30

# %%
test_images_list = create_file_list(test_images_path)
print('Number of test images: {:d}'.format(len(test_images_list)))
# Out:
# Number of test images: 31

# %%
img_0 = io.imread(train_images_list[0])
print('Image shape: {}'.format(img_0.shape))
# Out:
# Image shape: (250, 250, 3)

# %% [markdown]
# We plot some images to have a look

# %%
def plot_raster(ax, list_images):
  index = 0
  for col in range(0, fig_cols):
    for row in range(0, fig_rows):
      img_natcol = io.imread(list_images[index])
      img_equalized = exposure.equalize_hist(img_natcol)
      ax[row, col].set_axis_off()
      ax[row, col].imshow(img_equalized)
      index += 1

# %%
fig_rows = 3
fig_cols = 3
fig, ax = plt.subplots(nrows=fig_rows, ncols=fig_cols, figsize=(10, 10))
plot_raster(ax, train_images_list)

# %% [markdown]
# We create the list of the masks for training, validation and test as well

# %%
train_labels_list = create_file_list(train_labels_path)
val_labels_list = create_file_list(val_labels_path)
test_labels_list = create_file_list(test_labels_path)

# %%
label_0 = io.imread(train_labels_list[0])
print('Mask shape: {}'.format(label_0.shape))
# Out:
# Mask shape: (250, 250, 3)

# %% [markdown]
# The binary values used in the masks are 0 and 255

# %%
label_0_unique = np.unique(label_0)
print('Unique values in the mask: {}'.format(label_0_unique))
# Out:
# Unique values in the mask: [  0 255]

# %% [markdown]
# We plot the masks of the images we saw before

# %%
fig, ax = plt.subplots(nrows=fig_rows, ncols=fig_cols, figsize=(10, 10))
plot_raster(ax, train_labels_list)

# %% [markdown]
# ## Data preparation
# We load the data into NumPy arrays for the training and validation. The images and masks must be converted into tensors and put in batches. We can load the data in memory since the size of the dataset is small.

# %%
import random
random.Random(1337).shuffle(train_images_list)
random.Random(1337).shuffle(train_labels_list)

# %% [markdown]
# We load images and masks into PIL format and convert them to NumPy arrays.

# %%
def path_to_input_image(path):
    return img_to_array(load_img(path, target_size=img_size))

# %%
def path_to_target(path):
    img = img_to_array(load_img(path, target_size=img_size, color_mode="grayscale"))
    img = img.astype("uint8") - 255
    return img

# %% [markdown]
# We create an array of 224x224 RGB images and binary masks, with values in {0, 1}, for training

# %%
img_size = (224, 224)
num_train_imgs = len(train_images_list)
train_input_imgs = np.zeros((num_train_imgs,) + img_size + (3,), dtype="float32")
train_targets = np.zeros((num_train_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_train_imgs):
    train_input_imgs[i] = path_to_input_image(train_images_list[i])
    train_targets[i] = path_to_target(train_labels_list[i])

# %%
train_input_imgs.shape, train_targets.shape
# Out:
# ((244, 224, 224, 3), (244, 224, 224, 1))

# %%
label_0_unique = np.unique(train_targets[0,:,:,0])
print('Unique values in the mask: {}'.format(label_0_unique))
# Out:
# Unique values in the mask: [0 1]

# %% [markdown]
# Then an array of RGB images and binary masks for validation

# %%
num_val_imgs = len(val_images_list)
val_input_imgs = np.zeros((num_val_imgs,) + img_size + (3,), dtype="float32")
val_targets = np.zeros((num_val_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_val_imgs):
    val_input_imgs[i] = path_to_input_image(val_images_list[i])
    val_targets[i] = path_to_target(val_labels_list[i])

# %%
val_input_imgs.shape
# Out:
# (30, 224, 224, 3)

# %% [markdown]
# and finally an array of RGB images and masks for test

# %%
num_test_imgs = len(test_images_list)
test_input_imgs = np.zeros((num_test_imgs,) + img_size + (3,), dtype="float32")
test_targets = np.zeros((num_test_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_test_imgs):
    test_input_imgs[i] = path_to_input_image(test_images_list[i])
    test_targets[i] = path_to_target(test_labels_list[i])

# %%
test_input_imgs.shape
# Out:
# (31, 224, 224, 3)

# %% [markdown]
# ### Data augmentation
# Since the dataset is a small one we use data augmentation to increase the number of images for training. We define a layer to be used at the beginning of our model

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %% [markdown]
# We can see the effect of the transformations applied to one image

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_images = data_augmentation(train_input_imgs)
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_images[0].numpy().astype("uint8"))
  plt.axis("off")

# %% [markdown]
# ## Building the encoder-decoder model
# We use again the encoder-decoder model we used in a previous semantic segmentation task. The model includes the data augmentation step, three convolutional blocks for the downsamplig, and three transpose convolutional blocks for upsampling.

# %%
def build_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    x = data_augmentation(inputs)

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model

# %%
model = build_model(img_size=img_size, num_classes=2)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 112, 112,  │        896 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 112, 112,  │          0 │ activation_15[0]… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 112, 112,  │      2,400 │ activation_16[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 112, 112,  │      4,736 │ activation_17[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 56, 56,    │      2,112 │ activation_15[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 56, 56,    │          0 │ max_pooling2d_3[… │
# │                     │ 64)               │            │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 56, 56,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 56, 56,    │      8,896 │ activation_18[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 56, 56,    │     17,664 │ activation_19[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │      8,320 │ add_7[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 28, 28,    │          0 │ max_pooling2d_4[… │
# │                     │ 128)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 28, 28,    │          0 │ add_8[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_10 │ (None, 28, 28,    │     34,176 │ activation_20[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_11 │ (None, 28, 28,    │     68,096 │ activation_21[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 14, 14,    │     33,024 │ add_8[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 14, 14,    │          0 │ max_pooling2d_5[… │
# │                     │ 256)              │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 14, 14,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 14, 14,    │    590,080 │ activation_22[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 14, 14,    │    590,080 │ activation_23[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 28, 28,    │          0 │ add_9[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │     65,792 │ up_sampling2d_9[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 28, 28,    │          0 │ up_sampling2d_8[… │
# │                     │ 256)              │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 28, 28,    │          0 │ add_10[0][0]      │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 28, 28,    │    295,040 │ activation_24[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 28, 28,    │    147,584 │ activation_25[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 56, 56,    │          0 │ add_10[0][0]      │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 56, 56,    │     32,896 │ up_sampling2d_11… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 56, 56,    │          0 │ up_sampling2d_10… │
# │                     │ 128)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 56, 56,    │          0 │ add_11[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_12 │ (None, 56, 56,    │     73,792 │ activation_26[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 56, 56,    │     36,928 │ activation_27[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 112, 112,  │          0 │ add_11[0][0]      │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 112, 112,  │      8,256 │ up_sampling2d_13… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 112, 112,  │          0 │ up_sampling2d_12… │
# │                     │ 64)               │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 112, 112,  │          0 │ add_12[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 112, 112,  │     18,464 │ activation_28[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 112, 112,  │      9,248 │ activation_29[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_15    │ (None, 224, 224,  │          0 │ add_12[0][0]      │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_14    │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 224, 224,  │      2,080 │ up_sampling2d_15… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 224, 224,  │          0 │ up_sampling2d_14… │
# │                     │ 32)               │            │ conv2d_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 224, 224,  │        578 │ add_13[0][0]      │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,058,690 (7.85 MB)
#  Trainable params: 2,054,914 (7.84 MB)
#  Non-trainable params: 3,776 (14.75 KB)

# %% [markdown]
# ## Model compilation
# We use the [sparse categorical crossentropy](https://keras.io/api/losses/probabilistic_losses/#sparsecategoricalcrossentropy-class) as the loss function. it is a probabilistic loss function that expects integer values as label classes. During the training phase the labels are the masks that assign a class to each pixel in the input image. The predicted labels are computed pixel-wise by the softmax activation function. The sparse categorical crossentropy loss function computes difference between the pixels' label and the predicted ones.

# %%
model.compile(optimizer=keras.optimizers.Adam(1e-4),
              loss="sparse_categorical_crossentropy", #)
              metrics=['accuracy'])

callbacks = [
    keras.callbacks.ModelCheckpoint("rooftop_segmentation.keras",
    save_best_only=True)
]

# %% [markdown]
# ## Model training
# We set the number of epochs, that is, the number of times we use the training set to update the model's weights, the batch size, that is, the number of (image, mask) pair to use before the model weights are updated.

# %%
history = model.fit(train_input_imgs, train_targets,
                    epochs=50,
                    callbacks=callbacks,
                    batch_size=5,
                    validation_data=(val_input_imgs, val_targets))
# Out:
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.7603 - loss: 1.3940 - val_accuracy: 0.6819 - val_loss: 0.6210
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8927 - loss: 0.3350 - val_accuracy: 0.8678 - val_loss: 0.4553
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9074 - loss: 0.2572 - val_accuracy: 0.8669 - val_loss: 0.5032
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9146 - loss: 0.2289 - val_accuracy: 0.8682 - val_loss: 0.6658
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9231 - loss: 0.2031 - val_accuracy: 0.8683 - val_loss: 0.6555
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9302 - loss: 0.1814 - val_accuracy: 0.8688 - val_loss: 1.0624
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9315 - loss: 0.1747 - val_accuracy: 0.8688 - val_loss: 1.1911
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9493 - loss: 0.1323 - val_accuracy: 0.8688 - val_loss: 1.0685
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9474 - loss: 0.1378 - val_accuracy: 0.8688 - val_loss: 1.4585
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9590 - loss: 0.1085 - val_accuracy: 0.8688 - val_loss: 1.3368
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9561 - loss: 0.1118 - val_accuracy: 0.8688 - val_loss: 1.3596
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9605 - loss: 0.1022 - val_accuracy: 0.8707 - val_loss: 1.0079
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9640 - loss: 0.0911 - val_accuracy: 0.8770 - val_loss: 0.7921
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9661 - loss: 0.0867 - val_accuracy: 0.9007 - val_loss: 0.3938
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9690 - loss: 0.0801 - val_accuracy: 0.8987 - val_loss: 0.4155
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9705 - loss: 0.0743 - val_accuracy: 0.8999 - val_loss: 0.4496
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9719 - loss: 0.0722 - val_accuracy: 0.9084 - val_loss: 0.4071
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9740 - loss: 0.0671 - val_accuracy: 0.9126 - val_loss: 0.3908
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9704 - loss: 0.0753 - val_accuracy: 0.9118 - val_loss: 0.3127
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9718 - loss: 0.0721 - val_accuracy: 0.9106 - val_loss: 0.3213
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9756 - loss: 0.0620 - val_accuracy: 0.9109 - val_loss: 0.3700
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9734 - loss: 0.0682 - val_accuracy: 0.9113 - val_loss: 0.3914
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9795 - loss: 0.0524 - val_accuracy: 0.9144 - val_loss: 0.3134
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9774 - loss: 0.0571 - val_accuracy: 0.9155 - val_loss: 0.3642
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9791 - loss: 0.0529 - val_accuracy: 0.9145 - val_loss: 0.3620
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9791 - loss: 0.0524 - val_accuracy: 0.9115 - val_loss: 0.3800
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9739 - loss: 0.0638 - val_accuracy: 0.9144 - val_loss: 0.3098
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9806 - loss: 0.0487 - val_accuracy: 0.9161 - val_loss: 0.3179
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9790 - loss: 0.0523 - val_accuracy: 0.9171 - val_loss: 0.3447
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9807 - loss: 0.0475 - val_accuracy: 0.9150 - val_loss: 0.3808
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9793 - loss: 0.0512 - val_accuracy: 0.9146 - val_loss: 0.2954
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9814 - loss: 0.0467 - val_accuracy: 0.9124 - val_loss: 0.3941
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9813 - loss: 0.0466 - val_accuracy: 0.9149 - val_loss: 0.3810
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9826 - loss: 0.0427 - val_accuracy: 0.9155 - val_loss: 0.3584
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9811 - loss: 0.0467 - val_accuracy: 0.9194 - val_loss: 0.3476
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9836 - loss: 0.0404 - val_accuracy: 0.9043 - val_loss: 0.3127
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9834 - loss: 0.0416 - val_accuracy: 0.9163 - val_loss: 0.3569
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9799 - loss: 0.0493 - val_accuracy: 0.9092 - val_loss: 0.4026
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9809 - loss: 0.0467 - val_accuracy: 0.9170 - val_loss: 0.3495
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9805 - loss: 0.0476 - val_accuracy: 0.9163 - val_loss: 0.3826
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9838 - loss: 0.0401 - val_accuracy: 0.9118 - val_loss: 0.3136
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9846 - loss: 0.0382 - val_accuracy: 0.9171 - val_loss: 0.3204
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9845 - loss: 0.0386 - val_accuracy: 0.9136 - val_loss: 0.4491
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9811 - loss: 0.0467 - val_accuracy: 0.9183 - val_loss: 0.3344
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9833 - loss: 0.0415 - val_accuracy: 0.9144 - val_loss: 0.3267
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9837 - loss: 0.0401 - val_accuracy: 0.9064 - val_loss: 0.3226
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9836 - loss: 0.0400 - val_accuracy: 0.9169 - val_loss: 0.3445
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9850 - loss: 0.0366 - val_accuracy: 0.9168 - val_loss: 0.4338
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9842 - loss: 0.0385 - val_accuracy: 0.9140 - val_loss: 0.4331
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9858 - loss: 0.0344 - val_accuracy: 0.9165 - val_loss: 0.3210

# %%
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]

# %%
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %%
plt.figure()
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Accuracy")
plt.legend(loc='lower right')

# %% [markdown]
# ## Model predictions
# We use the model with the lowest loss to predict the mask of an image that was not used for training. For each input image the model outputs a mask with two bands. One band contains the probability for a pixel to belong to the class 0, and the other band contains the probability for each pixel to belong to the class 1. Since in a binary classification the two probabilities are complementary we can use one of the two bands to plot the result. We set a threshold of 0.5 for a pixel probability to be in class 0 or 1.

# %%
best_model = keras.models.load_model("rooftop_segmentation.keras")

# %%
def plot_predicted_mask(test_img, test_mask, predicted_mask):
  fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(10, 10))
  predicted_mask_ch1 = np.expand_dims(predicted_mask, 2)

  ax[0].axis("off")
  ax[0].set_title('Test image')
  ax[0].imshow(array_to_img(test_image))
  ax[1].axis("off")
  ax[1].set_title('Test Mask')
  ax[1].imshow(array_to_img(test_mask))
  ax[2].axis("off")
  ax[2].set_title('Predicted Mask')
  ax[2].imshow(array_to_img(predicted_mask_ch1))

# %%
i = 8
test_image = test_input_imgs[i]
test_tensor = np.expand_dims(test_image, 0)
test_mask = test_targets[i]
predicted_mask_tensor = best_model.predict(test_tensor)
predicted_mask = predicted_mask_tensor[0,:,:,1]
predicted_mask[predicted_mask >= 0.5] = 1
predicted_mask[predicted_mask < 0.5] = 0
predicted_mask = predicted_mask.astype(int)
plot_predicted_mask(test_image,test_mask, predicted_mask)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %% [markdown]
# ## Performance metric
# We use *Intersection over Union*, (aka [Jaccard score](https://en.wikipedia.org/wiki/Jaccard_index)) as a metric for the model performance.

# %%
predicted_mask.shape
# Out:
# (224, 224)

# %%
predicted_mask_1d = predicted_mask.reshape(224*224)
predicted_mask_1d.shape
# Out:
# (50176,)

# %%
label_0_unique = np.unique(predicted_mask)
print('Unique values in the mask: {}'.format(label_0_unique))
# Out:
# Unique values in the mask: [0 1]

# %%
test_mask_2 = test_mask[:,:,0]
test_mask_2.shape
# Out:
# (224, 224)

# %%
test_mask_1d = test_mask_2.reshape(224*224)
test_mask_1d.shape
# Out:
# (50176,)

# %%
label_0_unique = np.unique(test_mask_2)
print('Unique values in the mask: {}'.format(label_0_unique))
# Out:
# Unique values in the mask: [0 1]

# %%
iou = jaccard_score(test_mask_1d, predicted_mask_1d, average='binary', pos_label=1) * 100
print('Intersection over Union score: {:.2f}%'.format(iou))
# Out:
# Intersection over Union score: 79.03%

# %%
product = test_mask_2 * predicted_mask
label_0_unique = np.unique(product)
print('Unique values in the mask: {}'.format(label_0_unique))
# Out:
# Unique values in the mask: [0 1]

# %%
product.shape
# Out:
# (224, 224)

# %%
y_true = np.array([[0, 0, 0],
                   [1, 1, 0],
                   [1, 1, 0]])

# %%
y_true.shape
# Out:
# (3, 3)

# %%
y_pred = np.array([[1, 1, 1],
                   [1, 0, 0],
                   [1, 0, 0]])
y_pred.shape
# Out:
# (3, 3)

# %%
y_true[1]
# Out:
# array([1, 1, 0])

# %%
y_pred[1]
# Out:
# array([1, 0, 0])

# %%
jaccard_score(y_true[1], y_pred[1])
# Out:
# np.float64(0.5)

# %%
np.sum(y_pred[1] * y_true[1])
# Out:
# np.int64(1)

# %%
def iou(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask * groundtruth_mask)
    union = np.sum(pred_mask) + np.sum(groundtruth_mask) - intersect
    iou = np.mean(intersect/union)
    return round(iou, 3)

# %%
iou(test_mask_1d, predicted_mask_1d) * 100
# Out:
# np.float64(79.0)
